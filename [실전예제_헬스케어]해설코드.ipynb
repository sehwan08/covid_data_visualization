# %% [markdown]
# #[실전예제]헬스케어 - 질병 데이터분석 '코로나 바이러스'

# %% [markdown]
# #코로나 바이러스 데이터 분석 - 환경 설정 및 데이터 구조 파악

# %% [markdown]
# ##1. 라이브러리 import 및 데이터 업로드

# %% [markdown]
# ###라이브러리 import

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# ###csv 파일 업로드

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# ## 2. 데이터 구조 파악하기

# %% [markdown]
# ###데이터 pandas로 불러오기

# %%
coronaDF = pd.read_csv("covid_19_clean_complete.csv")

# %% [markdown]
# ###데이터 확인하기

# %%
coronaDF
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 0              0       0          0       0  Eastern Mediterranean
# 1              0       0          0       0                 Europe
# 2              0       0          0       0                 Africa
# 3              0       0          0       0                 Europe
# 4              0       0          0       0                 Africa
# ...          ...     ...        ...     ...                    ...
# 49063        865      14        734     117                 Africa
# 49064       1691     483        833     375  Eastern Mediterranean
# 49065        354       7        328      19                 Africa
# 49066       7235      60       6028    1147                 Europe
# 49067        505      12        128     365                 Africa
#
# [49068 rows x 10 columns]

# %% [markdown]
# ###결측 값 확인

# %%
coronaDF.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %% [markdown]
# ### 데이터 타입 조회

# %%
coronaDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Date 정보 수정 (Object => datetime)

# %%
coronaDF['Date'] = pd.to_datetime(coronaDF['Date'])
coronaDF
# Out:
#       Province/State         Country/Region        Lat       Long       Date  \
# 0                NaN            Afghanistan  33.939110  67.709953 2020-01-22
# 1                NaN                Albania  41.153300  20.168300 2020-01-22
# 2                NaN                Algeria  28.033900   1.659600 2020-01-22
# 3                NaN                Andorra  42.506300   1.521800 2020-01-22
# 4                NaN                 Angola -11.202700  17.873900 2020-01-22
# ...              ...                    ...        ...        ...        ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100 2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388 2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300 2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100 2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600 2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 0              0       0          0       0  Eastern Mediterranean
# 1              0       0          0       0                 Europe
# 2              0       0          0       0                 Africa
# 3              0       0          0       0                 Europe
# 4              0       0          0       0                 Africa
# ...          ...     ...        ...     ...                    ...
# 49063        865      14        734     117                 Africa
# 49064       1691     483        833     375  Eastern Mediterranean
# 49065        354       7        328      19                 Africa
# 49066       7235      60       6028    1147                 Europe
# 49067        505      12        128     365                 Africa
#
# [49068 rows x 10 columns]

# %% [markdown]
# # 코로나 바이러스 데이터 분석 - 국가별 최신 확진자, 사망자, 회복자 데이터 분석

# %% [markdown]
# ### 최신 데이터만 남기기

# %%
latestDF = coronaDF[coronaDF['Date'] == max(coronaDF['Date'])]

# %% [markdown]
# ### 국가별 합계 구하기

# %%
latest_country_sum = latestDF.groupby('Country/Region')['Confirmed', 'Deaths', 'Recovered'].sum().reset_index()
latest_country_sum
# Out:
# C:\Users\Cha\AppData\Local\Temp/ipykernel_20616/3963485360.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   latest_country_sum = latestDF.groupby('Country/Region')['Confirmed', 'Deaths', 'Recovered'].sum().reset_index()
#          Country/Region  Confirmed  Deaths  Recovered
# 0           Afghanistan      36263    1269      25198
# 1               Albania       4880     144       2745
# 2               Algeria      27973    1163      18837
# 3               Andorra        907      52        803
# 4                Angola        950      41        242
# ..                  ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752
# 183      Western Sahara         10       1          8
# 184               Yemen       1691     483        833
# 185              Zambia       4552     140       2815
# 186            Zimbabwe       2704      36        542
#
# [187 rows x 4 columns]

# %% [markdown]
# ### 사망자 높은 국가순으로 정렬하기

# %%
latest_country_sum = latest_country_sum.sort_values(by='Confirmed', ascending=False).reset_index(drop=True)
latest_country_sum
# Out:
#             Country/Region  Confirmed  Deaths  Recovered
# 0                       US    4290259  148011    1325804
# 1                   Brazil    2442375   87618    1846641
# 2                    India    1480073   33408     951166
# 3                   Russia     816680   13334     602249
# 4             South Africa     452529    7067     274925
# ..                     ...        ...     ...        ...
# 182               Dominica         18       0         18
# 183  Saint Kitts and Nevis         17       0         15
# 184              Greenland         14       0         13
# 185               Holy See         12       0         12
# 186         Western Sahara         10       1          8
#
# [187 rows x 4 columns]

# %% [markdown]
# ### 데이터 전체 조회하기

# %%
latest_country_sum.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_6c9ff_row0_col1, #T_6c9ff_row0_col2, #T_6c9ff_row1_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_6c9ff_row0_col3 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_6c9ff_row1_col1 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_6c9ff_row1_col2 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_6c9ff_row2_col1 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_6c9ff_row2_col2 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_6c9ff_row2_col3 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_6c9ff_row3_col1 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_6c9ff_row3_col2, #T_6c9ff_row5_col1, #T_6c9ff_row6_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_6c9ff_row3_col3 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_6c9ff_row4_col1, #T_6c9ff_row9_col2, #T_6c9ff_row14_col3 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_6c9ff_row4_col2, #T_6c9ff_row18_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_6c9ff_row4_col3 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_6c9ff_row5_col2 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_6c9ff_row5_col3 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_6c9ff_row6_col2 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_6c9ff_row6_col3 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_6c9ff_row7_col1, #T_6c9ff_row11_col3 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_6c9ff_row7_col2, #T_6c9ff_row13_col1, #T_6c9ff_row13_col2, #T_6c9ff_row18_col2, #T_6c9ff_row20_col2 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_6c9ff_row7_col3 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_6c9ff_row8_col1, #T_6c9ff_row13_col3 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_6c9ff_row8_col2 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_6c9ff_row8_col3, #T_6c9ff_row20_col3, #T_6c9ff_row22_col2, #T_6c9ff_row29_col3, #T_6c9ff_row30_col2, #T_6c9ff_row32_col2, #T_6c9ff_row35_col2, #T_6c9ff_row37_col2, #T_6c9ff_row39_col2, #T_6c9ff_row40_col3, #T_6c9ff_row41_col2, #T_6c9ff_row47_col3, #T_6c9ff_row48_col2, #T_6c9ff_row52_col2, #T_6c9ff_row55_col2, #T_6c9ff_row58_col2, #T_6c9ff_row58_col3, #T_6c9ff_row60_col2, #T_6c9ff_row61_col2, #T_6c9ff_row63_col2, #T_6c9ff_row64_col2, #T_6c9ff_row65_col2, #T_6c9ff_row66_col1, #T_6c9ff_row66_col2, #T_6c9ff_row67_col1, #T_6c9ff_row67_col2, #T_6c9ff_row67_col3, #T_6c9ff_row68_col1, #T_6c9ff_row68_col2, #T_6c9ff_row69_col1, #T_6c9ff_row69_col2, #T_6c9ff_row70_col1, #T_6c9ff_row70_col2, #T_6c9ff_row71_col1, #T_6c9ff_row71_col2, #T_6c9ff_row72_col1, #T_6c9ff_row72_col2, #T_6c9ff_row72_col3, #T_6c9ff_row73_col1, #T_6c9ff_row73_col2, #T_6c9ff_row74_col1, #T_6c9ff_row75_col1, #T_6c9ff_row75_col3, #T_6c9ff_row76_col1, #T_6c9ff_row76_col2, #T_6c9ff_row76_col3, #T_6c9ff_row77_col1, #T_6c9ff_row77_col2, #T_6c9ff_row77_col3, #T_6c9ff_row78_col1, #T_6c9ff_row78_col2, #T_6c9ff_row78_col3, #T_6c9ff_row79_col1, #T_6c9ff_row79_col2, #T_6c9ff_row79_col3, #T_6c9ff_row80_col1, #T_6c9ff_row80_col2, #T_6c9ff_row80_col3, #T_6c9ff_row81_col1, #T_6c9ff_row81_col2, #T_6c9ff_row81_col3, #T_6c9ff_row82_col1, #T_6c9ff_row82_col2, #T_6c9ff_row83_col1, #
#T_6c9ff_row120_col2, #T_6c9ff_row120_col3, #T_6c9ff_row121_col1, #T_6c9ff_row121_col2, #T_6c9ff_row121_col3, #T_6c9ff_row122_col1, #T_6c9ff_row122_col2, #T_6c9ff_row122_col3, #T_6c9ff_row123_col1, #T_6c9ff_row123_col2, #T_6c9ff_row123_col3, #T_6c9ff_row124_col1, #T_6c9ff_row124_col2, #T_6c9ff_row124_col3, ...

# %% [markdown]
# # 코로나 바이러스 데이터 분석 - 시간에 따른 확진자, 사망자, 회복자 시각화

# %% [markdown]
# ###날짜별 확진자, 사망자, 회복자 합계 구하기

# %%
date_status = coronaDF.groupby('Date')['Confirmed', 'Deaths', 'Recovered'].sum()
date_status = date_status.sort_index()
date_status
# Out:
# C:\Users\Cha\AppData\Local\Temp/ipykernel_20616/2999123376.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   date_status = coronaDF.groupby('Date')['Confirmed', 'Deaths', 'Recovered'].sum()
#             Confirmed  Deaths  Recovered
# Date
# 2020-01-22        555      17         28
# 2020-01-23        654      18         30
# 2020-01-24        941      26         36
# 2020-01-25       1434      42         39
# 2020-01-26       2118      56         52
# ...               ...     ...        ...
# 2020-07-23   15510481  633506    8710969
# 2020-07-24   15791645  639650    8939705
# 2020-07-25   16047190  644517    9158743
# 2020-07-26   16251796  648621    9293464
# 2020-07-27   16480485  654036    9468087
#
# [188 rows x 3 columns]

# %% [markdown]
# ### 시간에 따른 누적 확진자, 사망자, 회복자 그래프 (seaborn lineplot)

# %%
plt.figure(figsize=(22,10))
plt.xticks(rotation = 45 )
sns.lineplot(data=date_status)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # 전세계 코로나 바이러스 감염 지도 표시 - folium 라이브러리 소개 및 설명

# %% [markdown]
# ### folium 사용해보기

# %%
import folium
m = folium.Map()
m

# %% [markdown]
# ### folium으로 서울 지도 표시하기

# %%
m = folium.Map(location=[37.715133, 126.734086])
m

# %% [markdown]
# ### zoom 조절하기

# %%
m = folium.Map(location=[37.559533, 126.972464], zoom_start=16)
m

# %% [markdown]
# ### CircleMarker 그리기

# %%
m = folium.Map(location=[37.559533, 126.972464], zoom_start=16)
folium.CircleMarker([37.559533, 126.972464], radius=100).add_to(m)
m

# %% [markdown]
# ### CircleMarker 색상, 채우기, 채우기 색상 설정

# %%
m = folium.Map(location=[37.559533, 126.972464], zoom_start=16)
folium.CircleMarker([37.559533, 126.972464], radius=100, color="#ef9008", fill="True", fill_color="#ef9008").add_to(m)
m

# %% [markdown]
# ### CircleMarker로 popup 표시

# %%
m = folium.Map(location=[37.559533, 126.972464], zoom_start=16)
folium.CircleMarker([37.559533, 126.972464], radius=100, color="#ef9008", fill="True", fill_color="#ef9008", popup="hi").add_to(m)
m

# %% [markdown]
# #전세계 코로나 바이러스 감염 지도 표시 - 전세계 코로나 바이러스 감염 지도 시각화

# %% [markdown]
# ### 국가별 최신 확진자 데이터 조회

# %%
latestDF

# %% [markdown]
# ### 지도에 전세계 국가별 확진자 수 CircleMarker로 표시

# %%
m = folium.Map(location=[0, 0], zoom_start=4)
for n in latestDF.index:
    folium.CircleMarker([latestDF['Lat'][n], latestDF['Long'][n]], radius = int(latestDF['Confirmed'][n]/1000)
    , color='red', fill="True", fill_color='red', popup=latestDF['Country/Region'][n] + ":" + str(latestDF['Confirmed'][n])).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
