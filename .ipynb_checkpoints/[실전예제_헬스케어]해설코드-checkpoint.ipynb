# %% [markdown]
# #[실전예제]헬스케어 - 질병 데이터분석 '코로나 바이러스'

# %% [markdown]
# #코로나 바이러스 데이터 분석 - 환경 설정 및 데이터 구조 파악

# %% [markdown]
# ##1. 라이브러리 import 및 데이터 업로드

# %% [markdown]
# ###라이브러리 import

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# ###csv 파일 업로드

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# ## 2. 데이터 구조 파악하기

# %% [markdown]
# ###데이터 pandas로 불러오기

# %%
coronaDF = pd.read_csv("covid_19_clean_complete.csv")

# %% [markdown]
# ###데이터 확인하기

# %%
coronaDF

# %% [markdown]
# ###결측 값 확인

# %%
coronaDF.isnull().sum()

# %% [markdown]
# ### 데이터 타입 조회

# %%
coronaDF.info()

# %% [markdown]
# ### Date 정보 수정 (Object => datetime)

# %%
coronaDF['Date'] = pd.to_datetime(coronaDF['Date'])
coronaDF

# %% [markdown]
# # 코로나 바이러스 데이터 분석 - 국가별 최신 확진자, 사망자, 회복자 데이터 분석

# %% [markdown]
# ### 최신 데이터만 남기기

# %%
latestDF = coronaDF[coronaDF['Date'] == max(coronaDF['Date'])]

# %% [markdown]
# ### 국가별 합계 구하기

# %%
latest_country_sum = latestDF.groupby('Country/Region')['Confirmed', 'Deaths', 'Recovered'].sum().reset_index()
latest_country_sum

# %% [markdown]
# ### 사망자 높은 국가순으로 정렬하기

# %%
latest_country_sum = latest_country_sum.sort_values(by='Confirmed', ascending=False).reset_index(drop=True)
latest_country_sum

# %% [markdown]
# ### 데이터 전체 조회하기

# %%
latest_country_sum.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row0_col2 {
#             background-color:  #b91419;
#             color:  #f1f1f1;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row0_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row1_col1 {
#             background-color:  #f34c37;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row1_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row1_col3 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row2_col1 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row2_col2 {
#             background-color:  #fcb89e;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row2_col3 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row3_col1 {
#             background-color:  #fcbda4;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row3_col2 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row3_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row4_col1 {
#             background-color:  #fcbea5;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row4_col2 {
#             background-color:  #fc997a;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row4_col3 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row5_col1 {
#             background-color:  #fcbfa7;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row5_col2 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row5_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row6_col1 {
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row6_col2 {
#             background-color:  #fee3d6;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row6_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row7_col1 {
#             background-color:  #fee3d7;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row7_col2 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row7_col3 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row8_col1 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row8_col2 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row8_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row9_col1 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row9_col2 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row9_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row10_col1 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row10_col2 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row10_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row11_col1 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row11_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row11_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row12_col1 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row12_col2 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row12_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row13_col1 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row13_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row13_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row14_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row14_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row14_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row15_col1 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row15_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row15_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row16_col1 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row16_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row16_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row17_col1 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row17_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row17_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row18_col1 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row18_col2 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row18_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row19_col1 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row19_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c0b6ff7c_6b9b_11ea_b85f_0242ac1c0002row19_col3 {
#             background-color:  #fff5f0;

# %% [markdown]
# # 코로나 바이러스 데이터 분석 - 시간에 따른 확진자, 사망자, 회복자 시각화

# %% [markdown]
# ###날짜별 확진자, 사망자, 회복자 합계 구하기

# %%
date_status = coronaDF.groupby('Date')['Confirmed', 'Deaths', 'Recovered'].sum()
date_status = date_status.sort_index()
date_status

# %% [markdown]
# ### 시간에 따른 누적 확진자, 사망자, 회복자 그래프 (seaborn lineplot)

# %%
plt.figure(figsize=(22,10))
plt.xticks(rotation = 45 )
sns.lineplot(data=date_status)

# %% [markdown]
# # 전세계 코로나 바이러스 감염 지도 표시 - folium 라이브러리 소개 및 설명

# %% [markdown]
# ### folium 사용해보기

# %%
import folium
m = folium.Map()
m

# %% [markdown]
# ### folium으로 서울 지도 표시하기

# %%
m = folium.Map(location=[37.715133, 126.734086])
m

# %% [markdown]
# ### zoom 조절하기

# %%
m = folium.Map(location=[37.559533, 126.972464], zoom_start=16)
m

# %% [markdown]
# ### CircleMarker 그리기

# %%
m = folium.Map(location=[37.559533, 126.972464], zoom_start=16)
folium.CircleMarker([37.559533, 126.972464], radius=100).add_to(m)
m

# %% [markdown]
# ### CircleMarker 색상, 채우기, 채우기 색상 설정

# %%
m = folium.Map(location=[37.559533, 126.972464], zoom_start=16)
folium.CircleMarker([37.559533, 126.972464], radius=100, color="#ef9008", fill="True", fill_color="#ef9008").add_to(m)
m

# %% [markdown]
# ### CircleMarker로 popup 표시

# %%
m = folium.Map(location=[37.559533, 126.972464], zoom_start=16)
folium.CircleMarker([37.559533, 126.972464], radius=100, color="#ef9008", fill="True", fill_color="#ef9008", popup="hi").add_to(m)
m

# %% [markdown]
# #전세계 코로나 바이러스 감염 지도 표시 - 전세계 코로나 바이러스 감염 지도 시각화

# %% [markdown]
# ### 국가별 최신 확진자 데이터 조회

# %%
latestDF

# %% [markdown]
# ### 지도에 전세계 국가별 확진자 수 CircleMarker로 표시

# %%
m = folium.Map(location=[0, 0], zoom_start=4)
for n in latestDF.index:
    folium.CircleMarker([latestDF['Lat'][n], latestDF['Long'][n]], radius = int(latestDF['Confirmed'][n]/1000)
    , color='red', fill="True", fill_color='red', popup=latestDF['Country/Region'][n] + ":" + str(latestDF['Confirmed'][n])).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
